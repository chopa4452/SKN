# %%
print(123)
# Out:
# 123

# %%
int num = 1
# Out:
#   Cell In[2], line 1
#     int num = 1
#         ^
# SyntaxError: invalid syntax

# %%
num = 1

# %%
print(num)
# Out:
# 1

# %%
num = "1"

# %%
print(num)
# Out:
# 1

# %% [markdown]
# 좌항은 변수명, 우항은 원시 문자열로 표현된 자료
#
# 좌항은 변수명, 우항은 team_name 변수에 담긴 값 "ohgiraffers"

# %%
team_name = "ohgiraffers"

my_team = team_name

print(my_team)
# Out:
# ohgiraffers

# %%
team_name = "ohgiraffers"
my_team = team_name

team_name = "giraffers_united"

print("team_name:" + team_name)
print("my_team:" + my_team)
# Out:
# team_name:giraffers_united
# my_team:ohgiraffers

# %%
x = 5
y = x
x = 10

print(x)
print(y)
# Out:
# 10
# 5

# %%
team_name = "skn-23기 화이팅!!"
print(team_name) 

Team_name = "skn-23기 fighting!!"
print(Team_name)

# 카멜케이스 : teamName (자바와 자바스크립트)
# Out:
# skn-23기 화이팅!!
# skn-23기 fighting!!

# %%
우리팀 = "skn-23기"
print(우리팀)
# Out:
# skn-23기

# %%
team_1_name = "skn-23기"
team_1_name
# Out:
# 'skn-23기'

# %%
20240101 = "오지라퍼스"
# Out:
#   Cell In[20], line 1
#     20240101 = "오지라퍼스"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
team_@_name = "오지라퍼스"
# Out:
#   Cell In[21], line 1
#     team_@_name = "오지라퍼스"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# 변수의 이름으로써 사용 불가능한 것들 확인

# %%
import keyword 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
10
# Out:
# 10

# %%
print(_)
print(_ * 3)
# Out:
# 10
# 30

# %%
x, _, z = (1, 2, 3)
print(x)
print(z)
# Out:
# 1
# 3

# %% [markdown]
# 코딩에서 *(에스터리스크)는 모든 것을 의미한다

# %%
x, *_, y = (1, 2, 3, 4, 5)
print(x)
print(y)
# Out:
# 1
# 5

# %%
for _ in range(3):
    print("Hello")
# Out:
# Hello
# Hello
# Hello

# %%
_internal_name = "one_module"
_internal_version = "1.0"

# %%
million = 1_000_000
print(million)
# Out:
# 1000000

# %%
for_ = "for blah"
print(for_)
# Out:
# for blah

# %% [markdown]
# _ 언더바 하나만 사용하면 내부용(private) 또는 값을 무시
# __ 언더바 두개를 사용하면 이름을 숨김
# __xx__ => 매직 매서드(파이썬에서 자동으로 호출)
