# %%
with open('diary10.txt', 'w', encoding='utf-8') as f:
    f.write("""
오늘은 파일 입출력을 배웠습니다.
다양한 파일 확장자와 접근 모드를 사용할 수 있다는 점
이 흥미로웠습니다.
""")

with open('diary10.txt', 'r', encoding='utf-8') as f:
    print(f.read())
# Out:
# 오늘은 파일 입출력을 배웠습니다.
# 다양한 파일 확장자와 접근 모드를 사용할 수 있다는 점
# 이 흥미로웠습니다.

# %%
import csv

# csv.writer() 사용하는 방법
with open('application10.csv', 'w', newline="", encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['회사명', '직무','결과'])
    writer.writerow(['회사A', '데이터 분석가','합격'])
    writer.writerow(['회사B', '소프트웨어 엔지니어,' '불합격'])
    writer.writerow(['회사C', '제품 관리자','진행 중'])

with open('application10.csv', 'r', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row)
        #print(row['회사명'], ['결과'])
# with open('application10.csv', 'r', newline='', encoding='utf-8') as f:
#     reader = csv.reader(f)
#     for row in reader:
#         print(row)

# 기본 방법
# with open('application10.csv', 'w', encoding='utf-8') as f:
#     f.write("""회사명,직무,결과
# 회사A,데이터 분석가,합격
# 회사B,소프트웨어 엔지니어,불합격
# 회사C,제품 관리자,진행 중            
# """)
    
# with open('application10.csv', 'r', encoding='utf-8') as f:
#     print(f.read())
# Out:
# {'회사명': '회사A', '직무': '데이터 분석가', '결과': '합격'}
# {'회사명': '회사B', '직무': '소프트웨어 엔지니어,불합격', '결과': None}
# {'회사명': '회사C', '직무': '제품 관리자', '결과': '진행 중'}

# %%
import csv
with open('system10.log', 'w', newline='', encoding='utf-8') as f:
    f.write("""[INFO] 2024-01-01 12:00:00: 시스템 시작
[WARN] 2024-01-01 12:05:00: 메모리 사용량 증가
[ERROR] 2024-01-01 12:10:00: 프로그램 종료
""")
    
with open('system10.log', 'r', encoding='utf-8') as f:
    for line in f:
        if "WARN" in line or "ERROR" in line:
            print(line.strip()) # strip() 라인 공백 사라지게 해주는 메서드
    
# 첫 번째 방법
# with open('system10.log', 'r', newline="", encoding='utf-8') as f:
#     reader = f.read()
#     for row in reader:
#         if "WARN" in row or "ERROR" in row:
#             print(row)
# Out:
# [WARN] 2024-01-01 12:05:00: 메모리 사용량 증가
#
# [ERROR] 2024-01-01 12:10:00: 프로그램 종료

# %%
import json

# json.dump()를 사용해서 푸는 방식
data = {
    "name" : "다람쥐",
    "favorite_foods" : ["도토리", "호두", "밤"]
}

with open('favorite_foods_10.json', 'w', encoding='utf-8') as f:
    json_files = json.dump(data, f, ensure_ascii=False)

with open('favorite_foods_10.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    print(data['favorite_foods'])

# 딕셔너리를 str로 저장하고 split()을 이용해서 푸는 방식
# with open('favorite_foods_10.json', 'w', encoding='utf-8') as f:
#     f.write('{"name" : "다람쥐","favorite_foods" : ["도토리", "호두", "밤"]}')

# with open('favorite_foods_10.json', 'r', encoding='utf-8') as f:
#     json_file = f.read()
#     print(json_file.split('[')[1].split(']')[0])
# Out:
# ['도토리', '호두', '밤']

# %% [markdown]
# 🔥 난이도 3 (기본 JSON 다루기)
# 문제 1: JSON에서 특정 키 값 읽기 (기본)
#
# squirrel_info.json 파일을 생성하고 다음 데이터를 저장하세요.
#
# {
#     "name": "다람쥐",
#     "age": 5,
#     "skills": ["나무타기", "도토리 저장하기"]
# }
#
#
# 그 후 파일을 읽어와 skills 리스트만 출력하세요.

# %%
import json

data = {
    "name" : "다람쥐",
    "age" : 5,
    "skills" : ["나무타기", "도토리 저장하기"]
}

with open('squirrel_info.json', 'w', encoding='utf-8') as f:
    json_file = json.dump(data, f, ensure_ascii=False, indent=4)

with open('squirrel_info.json', 'r', encoding='utf-8') as f:
    json_file = json.load(f)
    print(json_file["skills"])
    # for line in json_file:
    #     if "skills" in line:
    #         print(line)
# Out:
# ['나무타기', '도토리 저장하기']

# %% [markdown]
# 문제 2: JSON 리스트 읽기
#
# squirrel_friends.json 파일에 아래 데이터를 저장하세요.
#
# [
#     {"name": "쥐돌이", "age": 2},
#     {"name": "너구리", "age": 4},
#     {"name": "청설모", "age": 3}
# ]
#
#
# 파일을 읽어와 모든 친구의 이름만 출력하세요.

# %%
data = [
    {"name" : "쥐돌이", "age" : 2},
    {"name" : "너구리", "age" : 4},
    {"name" : "청솔모", "age" : 3}
]

with open('squirrel_friends.json', 'w', encoding='utf-8') as f:
    json_save = json.dump(data, f, ensure_ascii=False)

with open('squirrel_friends.json', 'r', encoding='utf-8') as f:
    json_save = json.load(f)
    for line in json_save:
        print(line["name"])
# Out:
# 쥐돌이
# 너구리
# 청솔모

# %%
import json

data = {
    "name" : "다람쥐",
    "skills": [
        {"name" : "나무타기", "level" : 3},
        {"name" : "도토리 찾기", "level" : 5},
        {"name" : "은신", "level" : 2}
    ]
}

with open('squirrel_skills.json', 'w', encoding='utf-8') as f:
    json_file = json.dump(data, f, ensure_ascii=False)

with open('squirrel_skills.json', 'r', encoding='utf-8') as f:
    json_file = json.load(f)
    #print(json_file["skills"][0]["level"])
    json_file = json_file["skills"]
    for line in json_file:
        if line["level"] >= 3:
            print(line)

    # for row in json_file:
    #     print(row)
# Out:
# {'name': '나무타기', 'level': 3}
# {'name': '도토리 찾기', 'level': 5}

# %% [markdown]
# 문제 4: JSON 파일에서 값 추가 후 저장
#
# squirrel_foods.json에 다음 데이터를 저장하세요.
#
# {
#     "foods": ["도토리", "밤"]
# }
#
#
# 파일을 읽은 후 foods에 “호두”를 추가해서
# 다시 JSON 파일에 저장하세요.

# %%
data = {
    "foods" : ["도토리", "밤"]
}

with open('squirrel_foods.json', 'w', encoding='utf-8') as f:
    json_file = json.dump(data, f, ensure_ascii=False)

with open('squirrel_foods.json', 'r', encoding='utf-8') as f:
    json_file = json.load(f)
    print(json_file)
    json_file["foods"].append("호두")
    print(json_file)
# Out:
# {'foods': ['도토리', '밤']}
# {'foods': ['도토리', '밤', '호두']}

# %% [markdown]
# 🔥 난이도 5 (여러 JSON 조합하기)
# 문제 5: 두 JSON 파일 합쳐서 새로운 JSON 만들기
#
# 파일 1: squirrel_basic.json
#
# {
#     "name": "다람쥐",
#     "age": 5
# }
#
#
# 파일 2: squirrel_stats.json
#
# {
#     "speed": 7,
#     "power": 4,
#     "wisdom": 6
# }
#
#
# 두 파일을 모두 읽어서
# 아래 형태의 새로운 squirrel_final.json을 생성하세요.
#
# {
#     "name": "다람쥐",
#     "age": 5,
#     "stats": {
#         "speed": 7,
#         "power": 4,
#         "wisdom": 6
#     }
# }

# %%
import json
import os
temp = {
    "name" : "다람쥐",
    "age" : 5
 }
with open('squirrel_basic.json', 'w', encoding='utf-8') as f:
    json.dump(temp, f, ensure_ascii=False)


temp2 = {
    "speed" : 7,
    "power" : 4,
    "wisdom" : 6
}
with open('squirrel_stats.json', 'w', encoding='utf-8') as f:
    json.dump(temp2, f, ensure_ascii=False)

with open('squirrel_basic.json', 'r', encoding='utf-8') as f:
    basic = json.load(f)

with open('squirrel_stats.json', 'r', encoding='utf-8') as f:
    stats = json.load(f)
    print({**basic, "stats" : stats})
# Out:
# {'name': '다람쥐', 'age': 5, 'stats': {'speed': 7, 'power': 4, 'wisdom': 6}}

# %% [markdown]
# 🔥 난이도 6 (고급 파싱 + 데이터 처리)
# 문제 6: 중첩 JSON에서 원하는 정보 추출하기
#
# squirrel_nested.json 파일에 아래 데이터를 저장하세요.
#
# {
#     "name": "다람쥐",
#     "tree": {
#         "location": "산속",
#         "foods": {
#             "nuts": ["도토리", "호두"],
#             "fruits": ["밤", "산딸기"]
#         }
#     }
# }
#
#
# JSON 파일을 읽은 뒤 nuts와 fruits 리스트를 모두 합쳐서 하나의 리스트로 출력하세요.
#
# 예:
# ["도토리", "호두", "밤", "산딸기"]

# %%
data = {
    "name" : "다람쥐",
    "tree" : {
        "location" : "산속",
        "foods" : {
            "nuts" : ["도토리", "호두"],
            "fruits" : ["밤", "산딸기"]
        }
    }
}

with open('squirrel_nested.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False)

with open('squirrel_nested.json', 'r', encoding='utf-8') as f:
    json_file = json.load(f)
    #print(json_file)

    # 간단하게 풀 수 있는 방법
    merged = json_file["tree"]["foods"]
    final_merged = merged["nuts"] + merged["fruits"]
    print(final_merged)

    # 이건 차례대로 파고드는 코드. 지저분한게 단점
    # json_file2 = json_file["tree"]
    # json_file3 = json_file2["foods"]
    # fruits = json_file3["fruits"]
    # nuts = json_file3["nuts"]
    # list_fruits = fruits + nuts
    # print(list_fruits)
# Out:
# ['도토리', '호두', '밤', '산딸기']

# %% [markdown]
# ### **문제 5: `.html` 파일 수정**
#
# 다람쥐는 자신의 이력서를 작성 중입니다. `resume.html` 파일을 다음 내용으로 생성하고 수정하세요.
#
# 1. `resume.html` 파일 생성 내용:
#
#     ```html
#     <html>
#         <head><title>다람쥐의 이력서</title></head>
#         <body>
#             <h1>다람쥐의 이력서</h1>
#             <p>경력: 신입</p>
#         </body>
#     </html>
#     ```
#
# 2. 수정 작업:
#     - `<p>` 태그 안의 "신입"을 "1년 경력"으로 변경하세요.
# 3. 수정된 파일을 읽어와 전체 내용을 출력하세요.

# %%
with open('resume10.html', 'w', encoding='utf-8') as f:
    f.write("""<html>
    <head><title>다람쥐의 이력서</title></head>
    <body>
        <h1>다람쥐의 이력서</h1>
        <p>경력: 신입</p>
    </body>
</html>
""")
    
with open('resume10.html', 'r', encoding='utf-8') as f:
    content = f.read()

content = content.replace("신입", "1년 경력")

with open('resume10.html', 'w', encoding='utf-8') as f:
    f.write(content)

with open('resume10.html', 'r', encoding='utf-8') as f:
    print(f.read())
# Out:
# <html>
#     <head><title>다람쥐의 이력서</title></head>
#     <body>
#         <h1>다람쥐의 이력서</h1>
#         <p>경력: 1년 경력</p>
#     </body>
# </html>

# %% [markdown]
# ### **문제 1: 모든 예외 처리**
#
# 다람쥐는 파일에서 데이터를 읽으려고 하지만, 파일이 없을 경우 프로그램이 중단되지 않도록 처리하고 싶습니다.
#
# 1. `data.txt` 파일을 읽으려고 시도하세요.
# 2. 파일이 없을 경우, `"파일이 존재하지 않습니다."`를 출력하세요.
# 3. 파일이 존재하면 파일 내용을 출력하세요.:

# %%
try:
    f = open('data.txt', 'r', encoding="utf-8")
    print(f.read())
    f.close()
except:
    print("파일이 존재하지 않습니다.")
# Out:
# 파일이 존재하지 않습니다.

# %% [markdown]
# ### **문제 2: 특정 예외 처리**
#
# 다람쥐는 사용자에게 나이를 입력받아 성인인지 확인하려고 합니다.
#
# 1. 사용자로부터 나이를 입력받아 정수로 변환하세요.
# 2. 입력값이 숫자가 아닐 경우, `"숫자를 입력해야 합니다."`를 출력하세요.
# 3. 숫자가 올바르게 입력되면 나이가 19 이상인지 확인하고, 19 이상이면 `"성인입니다."`, 그렇지 않으면 `"미성년자입니다."`를 출력하세요.

# %%
try:
    num = int(input("숫자를 입력하세요"))
    if num >= 19:
        print("성인입니다.")
    else:
        print("미성년자입니다.")
except:
    print("숫자를 입력해야합니다.")
# Out:
# 숫자를 입력해야합니다.

# %% [markdown]
# ### **문제 3: 특수 예외 상황과 오류 변수 사용**
#
# 다람쥐는 숫자 두 개를 입력받아 나누기를 수행하려고 합니다.
#
# 1. 사용자로부터 두 숫자를 입력받아 나누기를 수행하세요.
# 2. 첫 번째 숫자가 0으로 나누기를 시도하면 `"0으로 나눌 수 없습니다."`를 출력하세요.
# 3. 입력값이 숫자가 아니면 `"숫자를 입력해야 합니다."`를 출력하세요.
# 4. 오류 메시지를 출력할 때 발생한 오류 내용을 함께 출력하세요.

# %%
try:
    first_num = int(input("숫자 입력"))
    second_num = int(input("숫자 입력"))
    
    result = first_num / second_num
    print(result)
except ZeroDivisionError as e:
    print("0으로 나눌 수 없습니다.", e)
except:
    print("숫자를 입력하세요")
# Out:
# 숫자를 입력하세요

# %% [markdown]
# ### **문제 4: finally 블럭**
#
# 다람쥐는 프로그램 실행 후 파일 자원을 반드시 정리해야 합니다.
#
# 1. `log.txt` 파일을 읽으려고 시도하세요.
# 2. 파일을 여는 중 예외가 발생할 경우, `"파일을 열 수 없습니다."`를 출력하세요.
# 3. 예외 발생 여부와 상관없이 파일 자원을 정리하는 메시지 `"파일 자원 정리 완료"`를 출력하세요.

# %%
# 두 번째 방법

try:
    with open('log.txt', 'r', encoding='utf-8') as f:
        f.read()
except FileNotFoundError as e:
    print("파일을 열 수 없습니다.", e)
finally:
    print("파일 자원 정리 완료")
# 첫 번째 방법
# try:
#     f = open('log.txt', 'r', encoding='utf-8')
#     print(f.read())
#     f.close()
# except FileNotFoundError as e:
#     print("파일을 열 수 없습니다.", e)
# finally:
#     if f:
#         f.close()
#     print('파일 자원 정리 완료')
# Out:
# 파일을 열 수 없습니다. [Errno 2] No such file or directory: 'log.txt'
# 파일 자원 정리 완료

# %% [markdown]
# ### **문제 5: try-else 블럭**
#
# 다람쥐는 사용자로부터 숫자를 입력받아 2로 나눈 결과를 출력하려고 합니다.
#
# 1. 사용자로부터 숫자를 입력받아 정수로 변환하세요.
# 2. 입력값이 숫자가 아닐 경우 `"숫자를 입력해야 합니다."`를 출력하세요.
# 3. 숫자가 올바르게 입력되면 입력값을 2로 나눈 결과를 출력하세요.

# %%
try:
    num = int(input("숫자 입력"))
except:
    print("숫자를 입력해야 합니다.")
else:
    print(num / 2)
# Out:
# 숫자를 입력해야 합니다.
