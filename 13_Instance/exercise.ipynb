# %%
class Person:
    national = "korea"
    language = 'korean'

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greeting(self):
        return "Hello. This is python"
    
    def information(self):
        return "I am from " + self.national + "and I use" + self.language
    
    def favorite(self, color):
        return "I love " + color

# %%
capybara = Person("카피바라", 900)
Gorilla = Person("고릴라", 20)

print(capybara)
print(Gorilla)

print(capybara.national)
print(capybara.greeting())
print(Gorilla.information())
print(Gorilla.favorite("blue"))
# Out:
# <__main__.Person object at 0x000001F68B918980>
# <__main__.Person object at 0x000001F68B8D3750>
# korea
# Hello. This is python
# I am from koreaand I usekorean
# I love blue

# %%
class Character:    
    skills = []
    
    def __init__(self, nickname, type):
        self.nickname = nickname
        self.type = type
        
    def add_skill(self, skill):
        self.skills.append(skill)
    
    def show_skill(self):
        return self.type + ' ' + self.nickname + '님의 보유 스킬 ' + str(self.skills)

my_character = Character('산골짜기다람쥐', '전사')
your_character = Character('흑염룡의고릴라', '법사')
my_character.add_skill('곤봉 휘두르기')
your_character.add_skill('마법진 그려서 날려버리기')

print(my_character.show_skill())    # 전사 산골짜기다람쥐님의 보유 스킬 ['곤봉 휘두르기', '마법진 그려서 날려버리기']
# Out:
# 전사 산골짜기다람쥐님의 보유 스킬 ['곤봉 휘두르기', '마법진 그려서 날려버리기']

# %%
class Character:        
    def __init__(self, nickname, type):
        self.nickname = nickname
        self.type = type
        self.skills = []
        
    def add_skill(self, skill):
        self.skills.append(skill)
    
    def show_skill(self):
        return self.type + ' ' + self.nickname + '님의 보유 스킬 ' + str(self.skills)

my_character = Character('산골짜기다람쥐', '전사')
your_character = Character('흑염룡의고릴라', '법사')
my_character.add_skill('곤봉 휘두르기')
your_character.add_skill('마법진 그려서 날려버리기')

print(my_character.show_skill())    # 전사 산골짜기다람쥐님의 보유 스킬 ['곤봉 휘두르기']
# Out:
# 전사 산골짜기다람쥐님의 보유 스킬 ['곤봉 휘두르기']

# %%
class Character:
    nickname = "땅파먹는개미핥기"

    def __init__(self, nickname, type):
        self.nickname = nickname
        self.type = type
    

my_character = Character('카피바라', '용사')
print(my_character.nickname)
# Out:
# 카피바라
