# %%
fruits = ["orange", "apple", "pear", "banana", "kiwi", "apple"]
print(fruits)
# Out:
# ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple']

# %%
fruits[0]
# Out:
# 'orange'

# %%
rainbow_split = "빨-주-노-초-파-남-보"
print(rainbow_split.split("-"))
# Out:
# ['빨', '주', '노', '초', '파', '남', '보']

# %%
list1 = []
list2 = list()

print(list1)
print(list2)
print(list1 == list2)
# Out:
# []
# []
# True

# %%
list3 = list("hello")
print(list3)
list3[0]
# Out:
# ['h', 'e', 'l', 'l', 'o']
# 'h'

# %%
safari_list = ["bear", "koala", "gorila", "squireel"]
another_safari_list = ["Monkey", "Tiger", "Wolf"]

print(safari_list + another_safari_list)

# result = safari_list + another_safari_list
# print(result) 해도 결과값은 동일
# Out:
# ['bear', 'koala', 'gorila', 'squireel', 'Monkey', 'Tiger', 'Wolf']

# %%
safari_list = ["Bear", "Koala", "Gorila", "squireel"]
result = safari_list * 4

print(result)
# Out:
# ['Bear', 'Koala', 'Gorila', 'squireel', 'Bear', 'Koala', 'Gorila', 'squireel', 'Bear', 'Koala', 'Gorila', 'squireel', 'Bear', 'Koala', 'Gorila', 'squireel']

# %%
fruits = ["orange", "apple", "pear", "banana", "kiwi", "apple"]

print("apple:", fruits.count("apple"))
# Out:
# apple: 2

# %%
print("test:", fruits.count("test"))
# Out:
# test: 0

# %%
print("index:", fruits.index("apple"))
# Out:
# index: 1

# %%
print("index", fruits.index("apple", 3))
# Out:
# index 5

# %%
fruits.reverse()
print(fruits)
# Out:
# ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']

# %%
lst = [1,2,3,4,5]
lst.reverse()
print(lst)
# Out:
# [5, 4, 3, 2, 1]

# %%
lst = [1,2,3,4,5]
lst2 = reversed(lst)
print(lst)
print(lst2)

for x in lst2:
    print(x, end=' ')
# Out:
# [1, 2, 3, 4, 5]
# ...
# 5 4 3 2 1

# %%
fruits.append("pineapple")
print(fruits)
# Out:
# ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'pineapple']

# %%
random = ["apple", 1,2,3, ["orange", "kiwi"]]
print(random[4][0])
# Out:
# orange

# %%
fruits.extend(["rainbow fruit", "sweet lemon"]) # extend함수와 append의 차이는 반복이 가능한것만 넣을 수 있다
print(fruits)
# Out:
# ['apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'pineapple', 'rainbow fruit', 'sweet lemon', 'rainbow fruit', 'sweet lemon', 'rainbow fruit', 'sweet lemon']

# %%
fruits
# Out:
# ['apple',
#  'kiwi',
#  'banana',
#  'pear',
#  'apple',
#  'orange',
#  'pineapple',
#  'pineapple',
#  'rainbow fruit',
#  'sweet lemon',
#  'rainbow fruit',
#  'sweet lemon',
#  'rainbow fruit',
#  'sweet lemon']

# %%
fruits.insert(0, "monkey banana")
print(fruits)
# Out:
# ['monkey banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'pineapple', 'pineapple', 'rainbow fruit', 'sweet lemon', 'rainbow fruit', 'sweet lemon', 'rainbow fruit', 'sweet lemon']

# %%
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['sweet lemon', 'sweet lemon', 'sweet lemon', 'rainbow fruit', 'rainbow fruit', 'rainbow fruit', 'pineapple', 'pineapple', 'pear', 'orange', 'monkey banana', 'kiwi', 'banana', 'apple', 'apple']

# %%
fruits.sort(reverse=True)
print(fruits)
# Out:
# ['sweet lemon', 'sweet lemon', 'sweet lemon', 'rainbow fruit', 'rainbow fruit', 'rainbow fruit', 'pineapple', 'pineapple', 'pear', 'orange', 'monkey banana', 'kiwi', 'banana', 'apple', 'apple']

# %%
fruits.sort(key=len)
print(fruits)
# Out:
# ['pear', 'kiwi', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'pineapple', 'sweet lemon', 'sweet lemon', 'sweet lemon', 'rainbow fruit', 'rainbow fruit', 'rainbow fruit', 'monkey banana']

# %%
#fruits.sort(key=lamda x:(len(x), x))
print(fruits)
# Out:
# ['pear', 'kiwi', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'pineapple', 'sweet lemon', 'sweet lemon', 'sweet lemon', 'rainbow fruit', 'rainbow fruit', 'rainbow fruit', 'monkey banana']

# %%
temp = fruits.remove("kiwi")
print(temp)
print(fruits)
# Out:
# None
# ['pear', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'pineapple', 'sweet lemon', 'sweet lemon', 'sweet lemon', 'rainbow fruit', 'rainbow fruit', 'rainbow fruit', 'monkey banana']

# %%
lst = [2,3,5,1,4]
lst2 = sorted(lst)

print(lst)
print(lst2)
# Out:
# [2, 3, 5, 1, 4]
# [1, 2, 3, 4, 5]

# %%
temp = fruits.pop()
print(temp)
print(fruits)
# Out:
# monkey banana
# ['pear', 'apple', 'apple', 'orange', 'banana', 'pineapple', 'pineapple', 'sweet lemon', 'sweet lemon', 'sweet lemon', 'rainbow fruit', 'rainbow fruit', 'rainbow fruit']

# %%
plates = ["plate1", "plate2"]

plates.append("plate3")
plates.append("plate4")

print(plates)
# Out:
# ['plate1', 'plate2', 'plate3', 'plate4']

# %%
print(plates.pop())
print(plates)
print(plates.pop())
print(plates.pop())
print(plates)
# Out:
# plate4
# ['plate1', 'plate2', 'plate3']
# plate3
# plate2
# ['plate1']

# %%
plates.remove("plate1")
print(plates)
# Out:
# []

# %%
plates.append("plate1")
print(plates)
# Out:
# ['plate1', 'plate1']

# %%
abclist = ["A", "B", "C", "D", "E"]
print(abclist)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
del abclist[0]
print(abclist)
# Out:
# ['B', 'C', 'D', 'E']

# %%
abclist.append("F")
print(abclist)
del abclist[1:3] #[시작:끝-1]
print(abclist)
# Out:
# ['B', 'E', 'F', 'F']
# ['B', 'F']

# %%
del abclist[:]
print(abclist)
# Out:
# []

# %%
del abclist
print(abclist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 del abclist
# ----> 2 print(abclist)
#
# NameError: name 'abclist' is not defined

# %%
from collections import deque

dq = deque()

dq.append("a")
dq.append("b")
dq.append("c")

print(dq)
# Out:
# deque(['a', 'b', 'c'])

# %%
dq.appendleft("x")
print(dq)
# Out:
# deque(['x', 'a', 'b', 'c'])

# %%
value = dq.pop()
print(value)

left_value = dq.popleft()
print(left_value)

print(dq)
# Out:
# c
# x
# deque(['a', 'b'])

# %%
tuples = (1,2, "hello")
print(tuples)
print(tuples[0])
print(tuples[1])
print(tuples[2])
# Out:
# (1, 2, 'hello')
# 1
# 2
# hello

# %%
tuples = (1,2, "hello"), ("test",1,2,3,4)
print(tuples)
print(tuples[0])
print(tuples[1][0])
# Out:
# ((1, 2, 'hello'), ('test', 1, 2, 3, 4))
# (1, 2, 'hello')
# test

# %%
no_wrap_tuples = 1,2,3
print(no_wrap_tuples)
# Out:
# (1, 2, 3)

# %%
tuples = (1,2, "hello"), ("test",1,2,3,4)
tuples[0] = (1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 tuples = (1,2, "hello"), ("test",1,2,3,4)
# ----> 2 tuples[0] = (1,2,3,4)
#
# TypeError: 'tuple' object does not support item assignment

# %%
testList = (1,2,3,4)
print(id(testList))

testList = (3,4,5)
print(id(testList))
# Out:
# 1918908832544
# 1918900905280

# %%
safari_tuple = ('Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf')
another_safari_tuple = ("monkey", "tiger", "wolf")

result = safari_tuple + another_safari_tuple
print(result)
# Out:
# ('Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf', 'monkey', 'tiger', 'wolf')

# %%
print(safari_tuple * 3)
# Out:
# ('Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf', 'Bear', 'Koara', 'Gorilla', 'Squirrel', 'Monkey', 'Tiger', 'Wolf')

# %%
print(len(safari_tuple + another_safari_tuple))
# Out:
# 10

# %%
x,y,z = 1,2,3
print(x,y,z)
print(type(x))
# Out:
# 1 2 3
# <class 'int'>

# %%
x,y = y,x
print(x,y)
# Out:
# 2 1

# %%
x,y,z = y,z,x
print(x,y,z)
# Out:
# 1 3 2

# %%
str1 = "ohgiraffers"
print(str1[0])
# Out:
# o

# %%
name = "ohgiraffers"
print(type(name))
# Out:
# <class 'str'>

# %%
address = "대한민국 서울시 서초구"
print(address[5]) # 서
print(address[9]) # 서
# Out:
# 서
# 서

# %%
location = ["서울특별시", "부신", "인천", "광주", "울산"]
print(location[3])
# Out:
# 광주

# %%
address = "대한민국 서울시 서초구"
print(address[-3]) # 
print(address[-7]) #
# Out:
# 서
# 서

# %%
location = ["서울특별시", "부신", "인천", "광주", "울산"]
print(location[-5])
# Out:
# 서울특별시

# %%
address = "대한민국 서울시 서초구"
print(address[4:8])
# Out:
#  서울시

# %%
location = ["서울특별시", "부산", "인천", "광주", "울산"]
print(location[2:])
print(location[2:5])
# Out:
# ['인천', '광주', '울산']
# ['인천', '광주', '울산']

# %%
address = '대한민국 서울시 서초구'
print(address[9:])
print(address[-3:])
print(address[1:12:4])
print(address[::-1])
# Out:
# 서초구
# 서초구
# 한서서
# 구초서 시울서 국민한대

# %%
location = ["서울특별시", "부산", "인천", "광주", "울산"]
print(location[3:]) # 광주 울산 출력
print(location[1:5]) # 부산 ~ 울산 출력
print(location[-4:]) # 부산 ~ 울산 출력
print(location[1:5:2]) # 부산 광주 출력
print(location[2::-1]) # 인천 부산 서울 순서대로
# Out:
# ['광주', '울산']
# ['부산', '인천', '광주', '울산']
# ['부산', '인천', '광주', '울산']
# ['부산', '광주']
# ['인천', '부산', '서울특별시']

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스')
print(nation[1:]) #미국~프랑스
print(nation[-3:]) #중국~프랑스
print(nation[1:5:2]) # 미국, 일본
print(nation[::-1]) # 역순
# Out:
# ('미국', '중국', '일본', '프랑스')
# ('중국', '일본', '프랑스')
# ('미국', '일본')
# ('프랑스', '일본', '중국', '미국', '대한민국')

# %%
# 문자열
address = '대한민국 서울시 서초구'
print('대한민국' in address)       # True
print('국민한대' in address)       # False
print('서울시서초구' in address)    # False
# Out:
# True
# False
# False

# %%
# 리스트
location = ['서울특별시', '부산광역시', '인천광역시', '광주광역시', '울산광역시']
print('광주광역시' in location)                   # True
print(['광주광역시', '부산광역시'] in location)    # False
print(['서울특별시', '부산광역시'] in location)    # False
# Out:
# True
# False
# False

# %%
# 튜플
nation = ('대한민국', '미국', '중국', '일본', '프랑스', ('대한민국', '미국'))
print('미국' in nation)                 # True
print(('대한민국', '미국') in nation)    # False
print(nation[5][1])
# Out:
# True
# True
# 미국

# %%
address = '대한민국 서울시 서초구'
print(len(address)) # 12
# Out:
# 12

# %%
location = ["서울", "부산", "인천", "광주", "울산"]
print(len(location)) # 5
# Out:
# 5

# %%
nation = ('대한민국', '미국', '중국', '일본', '프랑스', ('대한민국', '미국'))
print(len(nation)) # 6
# Out:
# 6

# %% [markdown]
# ### **문제 1**
#
# 아래 조건에 맞게 리스트를 선언하고 결과를 출력하세요.
#
# 1. `fruits`라는 리스트에 다음 요소를 저장하세요.
#     - `'apple', 'banana', 'cherry'`.
# 2. `print()`를 사용해 `fruits`의 첫 번째 요소와 세 번째 요소를 출력하세요.

# %%
fruits = ['apple', 'banana', 'cheery']
print(fruits[0], fruits[2])
# Out:
# apple cheery

# %% [markdown]
# numbers = [1,2,3,4,5]
# print(len(numbers))

# %%
numbers = [1,2,3,4,5]
print(len(numbers))
# Out:
# 5

# %% [markdown]
# ### **문제 3**
#
# 다음 조건에 맞게 리스트를 조작하세요.
#
# 1. `animals` 리스트에 `'cat', 'dog', 'bird'`를 저장하세요.
# 2. 이 리스트의 마지막에 `'fish'`를 추가하고, 리스트를 출력하세요.

# %%
animals = ['cat', 'dog', 'bird']
animals.append('fish')
print(animals)
# Out:
# ['cat', 'dog', 'bird', 'fish']

# %% [markdown]
# ### **문제 4**
#
# 아래 조건에 맞는 프로그램을 작성하세요.
#
# 1. `numbers` 리스트에 숫자 `3, 6, 9`를 저장하세요.
# 2. 리스트의 첫 번째 요소를 **2배**로 만들어 다시 저장하고, 리스트를 출력하세요.

# %%
numbers = [3,6,9]
# numbers[0] = numbers[0] * 2
numbers[0] *= 2
print(numbers)
# Out:
# [6, 6, 9]

# %% [markdown]
# ### **문제 5**
#
# 아래 문자열을 리스트로 변환하고 결과를 출력하세요.
#
# 1. 문자열 `'Python-is-fun'`을 `'-'`를 기준으로 분리하여 리스트로 만드세요.
# 2. 결과 리스트를 출력하세요.

# %%
temp = 'Python-is-fun'

print(temp.split("-"))
# Out:
# ['Python', 'is', 'fun']

# %% [markdown]
# ### **문제 6**
#
# 다음 조건에 맞게 **튜플**을 선언하고 활용하세요.
#
# 1. `my_tuple`이라는 이름으로 숫자 `10, 20, 30`을 가진 튜플을 선언하세요.
# 2. `my_tuple`의 두 번째 요소를 출력하세요.

# %%
my_tuple = (10, 20, 30)
print(my_tuple[1])
# Out:
# 20

# %% [markdown]
# ### **문제 7**
#
# 아래 조건에 맞게 리스트의 요소를 수정하세요.
#
# 1. `colors` 리스트에 `'red', 'blue', 'green'`을 저장하세요.
# 2. `'blue'`를 `'yellow'`로 변경하고 리스트를 출력하세요.

# %%
colors = ['red', 'blue', 'green']
colors[1] = 'yellow'
print(colors)
# Out:
# ['red', 'yellow', 'green']

# %% [markdown]
# ### **문제 9**
#
# 아래 조건에 맞게 리스트와 문자열을 활용하세요.
#
# 1. 리스트 `words`에 `'Life', 'is', 'too', 'short'`를 저장하세요.
# 2. 리스트의 요소를 공백으로 이어붙여 문자열 `'Life is too short'`를 출력하세요.

# %%
words = ["Life", "is", "too", "short"]
print(words)
words_result = " ".join(words)
print(words_result)

# result = ' '.join(words)
# Out:
# ['Life', 'is', 'too', 'short']
# Life is too short

# %% [markdown]
# ### **문제 10**
#
# 아래 조건에 맞는 프로그램을 작성하세요.
#
# 1. 리스트 `numbers`에 숫자 `1, 2, 3, 4, 5`를 저장하세요.
# 2. 슬라이싱을 이용하여 다음을 수행하세요:
#     - 리스트의 **처음 3개의 요소**를 출력하세요.
#     - 리스트의 **마지막 2개의 요소**를 출력하세요.
#     - 리스트의 **모든 요소를 역순**으로 출력하세요.

# %%
numbers = [1,2,3,4,5]
print(numbers[:3])
print(numbers[3:])
print(numbers[::-1])
# Out:
# [1, 2, 3]
# [4, 5]
# [5, 4, 3, 2, 1]

# %%
animals = ['tiger', 'cat', 'bear', 'rabbit']
result = animals[::-1]
print(result)
# Out:
# ['rabbit', 'bear', 'cat', 'tiger']

# %%
scores = [88, 92, 79 ,93, 85]
scores.sort()
print(scores)
# Out:
# [85, 93, 79, 92, 88]

# %%
names = ['지민', '태형', '정국', '남준', '석진']
print(names[2])
print(names[-1:])

colors = ['red', 'blue', 'green', 'yellow', 'pink']
colors[1] = "navy"
print(colors)

print(colors[2:4])

nums = [3, 7, 2, 9, 4, 2, 9]
print(nums.count(2))
print(nums.index(9))

animals = ['cat', 'dog', 'rabbit', 'elephant', 'zebra']
new_animals = sorted(animals)
print(new_animals)
new_animals.remove("rabbit")
print(new_animals)

fruits_delicious = "apple,banana,grape,melon"
new_fruits_delicious = fruits_delicious.split(",")
print(new_fruits_delicious)
print(new_fruits_delicious.index("grape"))

info = ('홍길동', 20, '서울')
name, age, city = info
print(info, name, age)
seven = (1,2,3)
eight = (4,5)
print(seven + eight)
# Out:
# 정국
# ['석진']
# ['red', 'navy', 'green', 'yellow', 'pink']
# ['green', 'yellow']
# 2
# 3
# ['cat', 'dog', 'elephant', 'rabbit', 'zebra']
# ['cat', 'dog', 'elephant', 'zebra']
# ['apple', 'banana', 'grape', 'melon']
# 2
# ('홍길동', 20, '서울') 홍길동 20
# (1, 2, 3, 4, 5)
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
text = "Python is fun!"
print(text[7:9])
print(text[::-1])
# Out:
# is
# !nuf si nohtyP

# %%
plates = []
plates.append('plate1')
plates.append('plate2')
plates.append('plate3')

last_dish = plates.pop()
print(plates)
last_second_dish = plates.pop()
print(plates)
# Out:
# ['plate1', 'plate2']
# ['plate1']

# %%
plate = ["apple"]
print(plate)
# Out:
# ['apple']
