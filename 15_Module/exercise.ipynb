# %%
import ohgiraffers_module
# import에 단일로 하면 패키지 모듈급

print(ohgiraffers_module.ohgiraffers)
print(ohgiraffers_module.gorilla())
print(ohgiraffers_module.tiger())
print(ohgiraffers_module.pig())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크왕
# 어흥
# 꿀꿀

# %%
from ohgiraffers_module import ohgiraffers, gorilla
# from엔 모듈 import엔 메서드

print(ohgiraffers)
print(gorilla())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크왕

# %%
import ohgiraffers_module as OG
print(OG.ohgiraffers)
print(OG.gorilla())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크왕

# %%
from ohgiraffers_module import ohgiraffers as oh, gorilla as gor
print(oh)
print(gor())
# Out:
# 국내최고 IT 전문교육 강사팀
# 크왕

# %%
import math

print(math.sqrt(16))
print(math.factorial(5))
print(math.pi)
# Out:
# 4.0
# 120
# 3.141592653589793

# %%
import sys # 시스템
import os # 운영체제

sys.path.append(os.path.dirname(os.path.dirname(__file__)))

import ohgiraffers_module
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import sys # 시스템
#       2 import os # 운영체제
# ----> 4 sys.path.append(os.path.dirname(os.path.dirname(__file__)))
#
# NameError: name '__file__' is not defined
