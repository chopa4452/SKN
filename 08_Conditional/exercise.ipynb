# %%
my_name = 'capybara'

if my_name == 'capybara':
    print(my_name)
# Out:
# capybara

# %%
my_name = 'capybara33'

if my_name == 'capybara':
    print("나는 카피바라 강사입니다!")
else:
    print("나는 카피바라 강사가 아닙니다!")
# Out:
# 나는 카피바라 강사가 아닙니다!

# %%
my_name = 'capybara'

if my_name == 'capybara':
    print("나는 카피바라 강사입니다!")
elif my_name == 'capybara1':
    print("나는 카피바라1 강사이다!")
elif my_name == 'capybara2':
    print("나는 카피바라2 강사이다!")
else:
    print("나는 카피바라 강사가 아닙니다!")
# Out:
# 나는 카피바라 강사입니다!

# %%
# 참일때 값 if 조건식 else 거짓일때 값
print("참" if True else "거짓")
print("참" if my_name == "capybara" else "거짓")
print("참" if my_name == "capybara22" else "거짓")
print("참" if False else "거짓")
# Out:
# 참
# 참
# 거짓
# 거짓

# %%
num = int(input('정수 입력 : '))
print('홀수' if num % 2 != 0 else '짝수')
# Out:
# 짝수

# %%
a = int(input('첫번째 정수 입력 : '))
b = int(input('두번째 정수 입력 : '))

big = a if a > b else b
small = a if a < b else b
print(big, small)
# Out:
# 6 5

# %%
a = int(input('첫번째 정수 입력 : '))
b = int(input('두번째 정수 입력 : '))

big, small = 0, 0
if a > b:
    big = a
    small = b
elif a < b:
    big = b
    small = a

print(small, big)
# Out:
# 5 10

# %%
print("=== OhGiraffers vending machine ===")
print("tiger: 우리는 1인 24시간 교대제로 간다")
print("monkey: 24시간 문의 환영, 다른 말로 하면?")
print("squirrel: 저도 하루에 너다섯 시간 자는데요?")
print("rabbit: 살아남는 사람이 강한 사람입니다.")
print("====================================")
print("만나고 싶은 선생님을 입력해 주세요")
input_teacher = input('만나고 싶은 선생님?')
print("====================================")

sleep_time = 0

match input_teacher:
    case "tiger":
        print("호랑이 선생님의 메타버스에 오신 것을 환영합니다.")
        sleep_time = 3
    case "monkey":
        print("원숭이 선생님의 밀림에 오신 것을 환영합니다.")
        sleep_time = 3.5
    case "squirrel":
        print("다람쥐 선생님의 매력의 늪에 오신 것을 환영합니다.")
        sleep_time = 5
    case "rabbit" :  
        print("토끼 선생님의 다정보스 랩에 오신 것을 환영합니다.")
        sleep_time = 5.2
    case _:
        print("공부할 마음이 없으신 건 아니죠?")

print("매일 " + str(sleep_time) + "시간의 수면이 예상됩니다.")
# print("매일", sleep_time, "시간의 수면이 예상됩니다.")
# Out:
# === OhGiraffers vending machine ===
# tiger: 우리는 1인 24시간 교대제로 간다
# monkey: 24시간 문의 환영, 다른 말로 하면?
# squirrel: 저도 하루에 너다섯 시간 자는데요?
# rabbit: 살아남는 사람이 강한 사람입니다.
# ...
# 만나고 싶은 선생님을 입력해 주세요
# ...
# 호랑이 선생님의 메타버스에 오신 것을 환영합니다.
# 매일 3시간의 수면이 예상됩니다.

# %% [markdown]
# ## **문제 1: 선택의 시작**
#
# **"다람쥐는 서울에 갈 것인가?"**
#
# 다람쥐는 서울로 상경할 계획을 세우고 있습니다. 다음 조건을 확인하세요.
#
# 1. 사용자에게 "서울에 갈 계획이 있나요? (y/n): "를 입력받으세요.
# 2. 입력값이 `'y'`이면 **"서울로 간다!"**를 출력하세요.

# %%
print("서울에 갈 계획이 있으신가요?")
plan = input("y or n로 입력해주세요")
if plan == "y":
    print("서울에 간다!")
else:
    print("서울에 가지 않습니다")
# Out:
# 서울에 갈 계획이 있으신가요?
# 서울에 가지 않습니다

# %%
print("서울에 갈 계획이 있으신가요?")
plan = input("y or n로 입력해주세요")
print("서울에 간다!" if plan.upper() == "Y" else "서울에 가지 않습니다.")
# Out:
# 서울에 갈 계획이 있으신가요?
# 서울에 가지 않습니다.

# %%
print("서울에 갈 계획이 있으신가요?")
plan = input("y or n로 입력해주세요")

match plan:
    case "y":
        print("서울에 간다!")
    case "n":
        print('서울에 가지 않는다.')
    case _:
        print("y 혹은 n으로 입력하세요")
# Out:
# 서울에 갈 계획이 있으신가요?
# y 혹은 n으로 입력하세요

# %% [markdown]
# ## **문제 2: 짐 싸기**
#
# **"다람쥐는 짐을 싸야 할까?"**
#
# 다람쥐는 서울에 가기로 마음먹었지만 짐을 싸야 할지 고민하고 있습니다.
#
# 1. 사용자에게 "집에 있는 가구를 다 가져갈까요? (y/n): "를 입력받으세요.
# 2. 입력값이 `'n'`이면 **"서울에서 가구를 새로 산다."**를 출력하세요.

# %%
print("집에 있는 가구를 다 가져갈까요?")
furniture = input().upper()

if furniture == 'Y':
    print("가져간다")
else:
    print("서울에서 가구를 새로 산다.")
# Out:
# 집에 있는 가구를 다 가져갈까요?
# 서울에서 가구를 새로 산다.

# %%
print("집에 있는 가구를 다 가져갈까요?")
furniture = input().upper()

match furniture:
    case 'Y':
        print("가져간다")
    case 'N':
        print("서울에서 가구를 새로 산다.")
    case _:
        print("y 혹은 n으로 입력하세요")
# Out:
# 집에 있는 가구를 다 가져갈까요?
# y 혹은 n으로 입력하세요

# %% [markdown]
# ## **문제 3: 기차표 구매**
#
# **"다람쥐는 기차표를 살 수 있을까?"**
#
# 다람쥐는 서울행 기차표를 구매하려 합니다.
#
# 1. 사용자에게 "현재 소지금은 얼마인가요? (숫자 입력): "을 입력받으세요.
# 2. 입력값이 `50000` 이상이면 **"기차표를 구매했다!"**를 출력하세요.

# %%
money = input(print("현재 소지금은 얼마인가요? (숫자 입력)"))


if int(money) >= 50000:
    print("기차표를 구매한다")
else:
    print("기차표를 구매하지 않습니다")
# Out:
# 현재 소지금은 얼마인가요? (숫자 입력)
# 기차표를 구매한다

# %%
print("현재 소지금은 얼마인가요? (숫자 입력)")
money = input()


match int(money):
    case _ if int(money) >= 50000:
        print("기차표를 구매한다.")
    case _:
        print("구매하지 않는다.")
# Out:
# 현재 소지금은 얼마인가요? (숫자 입력)
# 기차표를 구매한다.

# %%
print("현재 소지금은 얼마인가요? (숫자 입력)")
money = input()

test = 50000
match int(money) >= 50000:
    case True:
        print("기차표를 구매한다.")
    case False:
        print("구매하지 않는다.")
# Out:
# 현재 소지금은 얼마인가요? (숫자 입력)
# 기차표를 구매한다.

# %% [markdown]
# ## **문제 4: 서울 도착**
#
# **"다람쥐는 서울에 도착했다. 날씨가 좋을까?"**
#
# 서울에 도착한 다람쥐는 날씨에 따라 이동할 계획입니다.
#
# 1. 사용자에게 "오늘 서울 날씨는 맑음인가요? (y/n): "를 입력받으세요.
# 2. 입력값이 `'y'`이면 **"서울 구경을 나간다."**를 출력하세요.
# 3. 입력값이 `'n'`이면 **"집에서 쉰다."**를 출력하세요.

# %%
print("오늘 서울 날씨는 맑음인가요? (y/n)")
weather = input()
if weather == 'y':
    print("서울 구경을 나간다")
else:
    print("집에서 쉰다")
# Out:
# 오늘 서울 날씨는 맑음인가요? (y/n)
# 집에서 쉰다

# %% [markdown]
# ## **문제 5: 집 구하기**
#
# **"다람쥐는 어디에 살까?"**
#
# 서울에서 집을 구해야 하는 다람쥐는 예산에 따라 집을 선택합니다.
#
# 1. 사용자에게 "월세 예산은 얼마인가요? (숫자 입력): "를 입력받으세요.
# 2. 입력값이 `1000000` 이하이면 **"고시원에서 산다."**를 출력하세요.
# 3. 그 외의 경우 **"원룸을 계약한다."**를 출력하세요.

# %%
print("월세 예산은 얼마인가요? (숫자 입력)")
money = input()
if int(money) <= 100000:
    print("고시원에서 산다")
else:
    print("원룸을 계약한다")
# Out:
# 월세 예산은 얼마인가요? (숫자 입력)
# 원룸을 계약한다

# %% [markdown]
# ## **문제 6: 직장 찾기**
#
# **"다람쥐는 직장을 구해야 한다!"**
#
# 다람쥐는 서울에서 일자리를 찾고 있습니다. 직장에 따라 일의 강도가 다릅니다.
#
# 1. 사용자에게 "원하는 직장 종류를 입력하세요 (프리랜서/중소기업/대기업): "를 입력받으세요.
# 2. 입력값이 `'프리랜서'`이면 **"시간은 자유롭지만 불안정하다."**를 출력하세요.
# 3. 입력값이 `'중소기업'`이면 **"안정적이지만 일이 많다."**를 출력하세요.

# %%
print("원하는 직장 종류를 입력하세요 (프리랜서/중소기업/대기업)")
work = input()
if work == '프리랜서':
    print("시간은 자유롭지만 불안정하다")
elif work == "중소기업":
    print("안정적이지만 일이 많다.")
else:
    print("대기업이 최고일까")
# Out:
# 원하는 직장 종류를 입력하세요 (프리랜서/중소기업/대기업)
# 대기업이 최고일까

# %% [markdown]
# ## **문제 7: 생활 루틴 정하기**
#
# **"다람쥐는 서울에서 생활 루틴을 정해야 한다."**
#
# 서울 생활에 적응한 다람쥐는 하루 루틴을 정하려 합니다.
#
# 1. 사용자에게 "아침에 일어나는 시간을 입력하세요 (숫자 입력, 6~10): "를 입력받으세요.
# 2. 입력값이 6이면 **"운동을 한다."**를 출력하세요.
# 3. 입력값이 7이면 **"공부를 한다."**를 출력하세요.
# 4. 입력값이 8이면 **"바로 출근 준비를 한다."**를 출력하세요.

# %%
print("평소에 일어나는 시간이 어떻게 되십니까. 숫자입력, 6~10")
wake_up = input()
if int(wake_up) == 6:
    print("운동을 한다")
elif int(wake_up) == 7:
    print("공부를 한다")
elif int(wake_up) == 8:
    print("바로 출근 준비를 한다.")
else:
    print("늦잠을 잤다")
# Out:
# 평소에 일어나는 시간이 어떻게 되십니까. 숫자입력, 6~10
# 늦잠을 잤다

# %% [markdown]
# ## **문제 8: 주말 계획**
#
# **"다람쥐의 주말 계획은?"**
#
# 주말이 되자 다람쥐는 여유로운 시간을 보내려 합니다.
#
# 1. 사용자에게 "오늘 날씨가 어떤가요? (맑음/비/눈): "를 입력받으세요.
# 2. 입력값이 `'맑음'`이면 **"한강에 가서 피크닉을 즐기는 척하며 일을 한다."**를 출력하세요.
# 3. 입력값이 `'비'`이면 **"집에서 빗소리를 ASMR 삼아 일을 한다."**를 출력하세요.
# 4. 입력값이 `'눈'`이면 **"전기장판 안에서 귤을 까먹으며 일을 한다."**를 출력하세요.
# 5. 그 외의 값이 입력되면 **"암막 커튼 때문에 일어나지 못했다. 푹 잘 수 있군, 럭키비키잖아?"**를 출력하세요.

# %%
print("오늘 날씨가 어떤가요? (맑음, 비, 눈)")
today_weather = input()

if today_weather == '맑음':
    print("한강에 가서 피크닉을 즐기는 척하며 일을 한다.")
elif today_weather == '비':
    print("집에서 빗소리를 ASMR 삼아 일을 한다.")
elif today_weather == '눈':
    print("전기장판 안에서 귤을 까먹으며 일을 한다.")
else:
    print("암막 커튼 때문에 일어나지 못했다. 푹 잘 수 있군, 럭키비키잖아?")
# Out:
# 오늘 날씨가 어떤가요? (맑음, 비, 눈)
# 암막 커튼 때문에 일어나지 못했다. 푹 잘 수 있군, 럭키비지잖아?
