# %%
import reporting as re
import task_tracking as tt

print(tt.start_task("코드 리뷰"))
print(tt.end_task("코드 리뷰"))
print(re.generate_report("코드 리뷰"))
# Out:
# 작업 '코드 리뷰' 시작됨.
# 작업 '코드 리뷰' 종료됨.
# '코드 리뷰' 작업 보고서 생성됨.
